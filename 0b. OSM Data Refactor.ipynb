# %%
#this dataset is the open streetmap dataset for edmonton, it has all amenities provided by OSM in their dat

import pandas
import json

# %%
df = pandas.read_json('amenities-edmonton.json.gz',lines=True)

# %%
count = df['name'].unique()

# %%
len(count)

df['name'] = df['name'].astype(str)

# %%
# finds all unique categories, appends them, and sorts
all_categories = df['name'].unique().tolist()
all_categories = ', '.join(all_categories)
all_categories = all_categories.split(', ')
all_categories = list(set(all_categories))
all_categories
# Out:
# ['Kepler Academy College Plaza',
#  'McCauley Community Daycare',
#  'Rose & Crown',
#  'Canada Post Box',
#  'Shiva Daycare',
#  'Fumaca Brazilian Steakhouse',
#  'Little Caesars',
#  'Pediatric Clinic Dr. J Brar',
#  "Nitza's Pizza",
#  'HSBC',
#  'Hansik',
#  'Engineering for Kids',
#  'Masjid Annoor',
#  'Jumbo Dim Sum & Dining',
#  "Gini's Restaurant",
#  'MoneyGram',
#  'Noodle Street',
#  'Allegro',
#  "Sarah's Kitchen",
#  'Bohemia',
#  'Easyfinancial',
#  "Joey's Bell Tower",
#  'High Note Bar & Grill',
#  'Ragazzi Bistro',
#  'Spruce Grove Dental Clinic',
#  'Petrolia Medical Centre',
#  'Clean Car Wash',
#  'Nolan Drugs',
#  'Jade Village',
#  'Menjiro Ramen',
#  'Burton Denture Clinic',
#  'Tokyo Express',
#  'Your Pizza Guy',
#  'Famous Donair',
#  'Tesla Supercharger',
#  "Julio's Barrio",
#  'Aspen Pharmacy',
#  'The Burg',
#  'TacoTime Cantina',
#  'Red Star',
#  'Nara Hookah Lounge',
#  'Country Boyz',
#  'Annoor Islamic Centre',
#  'New Tan Restaurant',
# ...
